# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Advertising.csv")
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
from sklearn.linear_model import RidgeCV

# %%
ridge_cv=RidgeCV(alphas=[0.01, 0.05, 0.1, 0.5],scoring='neg_mean_squared_error')

# %%
x=df.drop("sales",axis=1)
y=df["sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_converter=PolynomialFeatures(degree=3)
poly_features=poly_converter.fit_transform(x)

# %%
X_train,X_test,y_train,y_test=train_test_split(poly_features,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
ridge_cv.fit(X_train,y_train)
# Out:
# RidgeCV(alphas=[0.01, 0.05, 0.1, 0.5], scoring='neg_mean_squared_error')

# %%
test_pred=ridge_cv.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
MAE=mean_absolute_error(y_test,test_pred)
RMSE=np.sqrt(mean_squared_error(y_test,test_pred))

# %%
MAE,RMSE
# Out:
# (0.41018731841100087, np.float64(0.5829610860934311))
